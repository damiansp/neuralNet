# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import numpy as np
import tensorflow as tf
import time

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from os.path import isfile, isdir
from tqdm import tqdm
from urllib.request import urlretrieve
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(
        unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import random
from collections import Counter

def get_subsampling_prob(threshold, frequency):
    return 1 - np.sqrt(threshold / frequency)

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count / total_count for word, count in word_counts.items()}
p_drop = {word: get_subsampling_prob(threshold, freqs[word]) 
          for word in word_counts}
train_words = [word for word in int_words 
               if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.choice(range(window_size)) + 1 
    start = max(0, idx - R)
    stop  = min(R + idx, len(words))
    target_words = set(words[start:idx] + words[idx + 1:stop + 1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words) // batch_size
    
    # only full batches
    words = words[:n_batches * batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx + batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x] * len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()

with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 

with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(
        tf.random_uniform([n_vocab, n_embedding], -1, 1))
    
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100

with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding],
                                                stddev=0.1))
    
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id 
    # implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), 
                                            valid_size // 2))
    valid_examples = np.append(
        valid_examples, 
        random.sample(range(1000, 1000 + valid_window), valid_size//2))
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, 
                                             valid_dataset)
    similarity = tf.matmul(valid_embedding, 
                           tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs + 1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()

        for x, y in batches:    
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed 
                # every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
            
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6375 0.2606 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6159 0.2641 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4993 0.2676 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6261 0.2619 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5330 0.2638 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5190 0.2646 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5699 0.2521 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5386 0.2552 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4917 0.2472 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4245 0.2463 sec/batch
# Nearest to he: passant, commit, reciting, gametophyte, fairfax, beds, maneuverable, brahmacharya,
# Nearest to their: darboux, prophetess, incursion, decry, ecsc, colds, peacemaking, dgps,
# Nearest to over: st, aggregates, jonson, city, firefox, zout, injected, basica,
# Nearest to eight: interstates, baresi, fidel, basketball, ccgs, circus, afford, syncretic,
# Nearest to may: suda, normalized, dendritic, buprenorphine, stripping, nadezhda, gopala, altruist,
# Nearest to use: refund, starve, chanced, forefather, prolific, somali, resigns, collingridge,
# Nearest to were: lock, poecilia, depot, herbivorous, farben, sultana, landesverband, rabbits,
# Nearest to a: davidoff, maclachlan, fries, motels, blunder, affaire, roald, construction,
# Nearest to bbc: businesspeople, gibraltarian, servicing, interpreter, learns, tom, rouge, steadfast,
# Nearest to pope: bara, dario, ldf, potency, gerlach, ouse, reflect, convinces,
# Nearest to derived: biotite, tabulate, anegada, anaphylaxis, independent, woodwinds, reputedly, broader,
# Nearest to applied: bowie, hawkwind, kfar, biathlon, makhuwa, mpaa, throughput, inaugurated,
# Nearest to except: nearing, ahijah, mahilyow, porosity, twins, perez, erimus, stagings,
# Nearest to scale: freemen, anecdote, montreux, therese, parodies, potter, worldwide, corinthian,
# Nearest to troops: mandarin, solid, pinguinus, chardin, closed, zant, roo, ximinez,
# Nearest to engineering: kennewick, example, wrangler, outlying, bodo, entorhinal, aquilegia, extending,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5134 0.2516 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4003 0.2474 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3260 0.2504 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2578 0.2478 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1621 0.2486 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1630 0.2468 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1179 0.2474 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0790 0.2471 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0152 0.2475 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0024 0.2482 sec/batch
# Nearest to he: commit, beds, passant, reciting, championships, gm, resulted, protein,
# Nearest to their: darboux, incursion, described, end, prophetess, decry, affordable, administrative,
# Nearest to over: city, st, injected, had, tourism, aggregates, shape, zout,
# Nearest to eight: interstates, fidel, basketball, afford, maintains, circus, baresi, coordinates,
# Nearest to may: sum, earth, suda, normalized, given, metal, stripping, via,
# Nearest to use: refund, prolific, started, chanced, starve, newcastle, primarily, resigns,
# Nearest to were: lock, rabbits, depot, herbivorous, poecilia, plants, farben, persons,
# Nearest to a: davidoff, motels, construction, fries, maclachlan, categories, interest, phylogeny,
# Nearest to bbc: businesspeople, tom, learns, phone, interpreter, sits, rouge, promise,
# Nearest to pope: bara, dario, leading, potency, reflect, outreach, lynch, gerlach,
# Nearest to derived: biotite, broader, independent, tabulate, reputedly, manufactured, imprisoned, anaphylaxis,
# Nearest to applied: bowie, inaugurated, mpaa, kfar, twelfth, biathlon, maintain, sector,
# Nearest to except: twins, nearing, than, synonymous, perez, all, entirely, arctos,
# Nearest to scale: anecdote, freemen, worldwide, therese, microsoft, parodies, potter, staccato,
# Nearest to troops: mandarin, solid, closed, holidays, chardin, entr, ul, element,
# Nearest to engineering: example, outlying, kennewick, still, extending, equipped, intentionally, expels,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9545 0.2523 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9163 0.2508 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8717 0.2500 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8756 0.2479 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8245 0.2484 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8494 0.2507 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7999 0.2495 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8168 0.2480 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7864 0.2510 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7956 0.2510 sec/batch
# Nearest to he: commit, gm, contradiction, reciting, cured, beds, fairfax, alois,
# Nearest to their: darboux, incursion, sequencer, affordable, worship, decry, prophetess, described,
# Nearest to over: city, st, firefox, aggregates, injected, tourism, had, zout,
# Nearest to eight: basketball, maintains, afford, interstates, fidel, roses, baresi, dickie,
# Nearest to may: sum, normalized, metal, earth, suda, stripping, naturalis, conjunction,
# Nearest to use: refund, prolific, chanced, register, starve, started, opponent, discerned,
# Nearest to were: rabbits, lock, herbivorous, farben, depot, plants, poecilia, chimborazo,
# Nearest to a: davidoff, roald, motels, fries, construction, blunder, phylogeny, affaire,
# Nearest to bbc: businesspeople, learns, promise, phone, sits, interpreter, tom, servicing,
# Nearest to pope: dario, bara, reflect, lynch, leading, likelihood, outreach, yeoman,
# Nearest to derived: broader, biotite, independent, tabulate, reputedly, ocs, anaphylaxis, woodwinds,
# Nearest to applied: bowie, inaugurated, twelfth, kfar, mpaa, maintain, millennium, hawkwind,
# Nearest to except: twins, nearing, synonymous, than, perez, porosity, morrison, arctos,
# Nearest to scale: anecdote, worldwide, freemen, microsoft, potter, therese, parodies, multiplications,
# Nearest to troops: mandarin, solid, holidays, closed, chardin, entr, survives, blocked,
# Nearest to engineering: example, outlying, equipped, kennewick, still, vinci, extending, expels,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7930 0.2537 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7427 0.2502 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7245 0.2505 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7098 0.2485 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7379 0.2515 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7106 0.2507 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7407 0.2527 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7279 0.2476 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6897 0.2489 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6634 0.2516 sec/batch
# Nearest to he: gm, reciting, commit, contradiction, alois, fairfax, cured, resulted,
# Nearest to their: darboux, incursion, sequencer, prophetess, adventurers, worship, colds, optimize,
# Nearest to over: city, had, firefox, st, aggregates, tourism, injected, zout,
# Nearest to eight: basketball, five, one, dickie, adjutant, maintains, french, rapport,
# Nearest to may: sum, normalized, nadezhda, suda, stripping, earth, millimeters, metal,
# Nearest to use: refund, starve, register, chanced, jacobian, informative, prolific, discerned,
# Nearest to were: rabbits, farben, herbivorous, lock, depot, plants, poecilia, vise,
# Nearest to a: roald, davidoff, fries, construction, motels, affaire, lest, blunder,
# Nearest to bbc: businesspeople, servicing, tom, interpreter, sits, taxonomy, promise, positivism,
# Nearest to pope: dario, bara, lynch, potency, eloquent, outreach, husbands, calcutta,
# Nearest to derived: biotite, tabulate, broader, independent, ocs, reputedly, woodwinds, anaphylaxis,
# Nearest to applied: bowie, mpaa, kfar, hawkwind, inaugurated, biathlon, maintain, pont,
# Nearest to except: nearing, twins, porosity, synonymous, than, morrison, perez, arctos,
# Nearest to scale: anecdote, freemen, worldwide, microsoft, potter, therese, parodies, multiplications,
# Nearest to troops: mandarin, holidays, chardin, delhi, solid, closed, roo, entr,
# Nearest to engineering: example, kennewick, outlying, equipped, vinci, still, expels, frame,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6795 0.2516 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6748 0.2506 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6224 0.2502 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6232 0.2479 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6274 0.2516 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6513 0.2506 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5644 0.1853 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5517 0.2495 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5294 0.2494 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5043 0.2519 sec/batch
# Nearest to he: reciting, commit, gm, alois, cured, resulted, fairfax, weiser,
# Nearest to their: darboux, optimize, prophetess, sequencer, colds, worship, incursion, affordable,
# Nearest to over: city, firefox, aggregates, injected, had, tourism, horsepower, navies,
# Nearest to eight: five, one, basketball, adjutant, french, laureate, argentine, interstates,
# Nearest to may: sum, normalized, suda, millimeters, summarizing, earth, nadezhda, metal,
# Nearest to use: refund, register, starve, informative, jacobian, somali, phone, chanced,
# Nearest to were: rabbits, herbivorous, farben, lock, poecilia, depot, vise, plants,
# Nearest to a: roald, davidoff, fries, fante, construction, motels, strains, categories,
# Nearest to bbc: businesspeople, servicing, tom, promise, taxonomy, ezra, rouge, seamless,
# Nearest to pope: dario, bara, lynch, niccolo, ans, husbands, calcutta, kerry,
# Nearest to derived: biotite, tabulate, broader, independent, ocs, reputedly, woodwinds, anaphylaxis,
# Nearest to applied: bowie, hawkwind, kfar, spectral, cannot, mpaa, conduction, biathlon,
# Nearest to except: nearing, twins, than, porosity, arctos, morrison, burnside, synonymous,
# Nearest to scale: anecdote, freemen, multiplications, worldwide, optical, microsoft, montreux, model,
# Nearest to troops: mandarin, delhi, holidays, chardin, roo, moines, entr, solid,
# Nearest to engineering: example, kennewick, equipped, vinci, outlying, wrangler, still, entorhinal,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4949 0.2576 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5213 0.2536 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4560 0.2529 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5357 0.2503 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4786 0.2527 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4713 0.2490 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4447 0.2493 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3928 0.2480 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4194 0.2517 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4308 0.2490 sec/batch
# Nearest to he: reciting, god, commit, cured, instructors, gm, resulted, alois,
# Nearest to their: darboux, colds, affordable, prophetess, worship, optimize, dgps, described,
# Nearest to over: city, injected, tourism, firefox, aggregates, horsepower, hudson, philological,
# Nearest to eight: five, basketball, interstates, adjutant, one, zero, maintains, rapport,
# Nearest to may: sum, normalized, summarizing, desirable, bilingualism, barricades, millimeters, stripping,
# Nearest to use: refund, starve, register, jacobian, somali, chanced, informative, phone,
# Nearest to were: rabbits, farben, herbivorous, depot, descendants, chimborazo, plants, poecilia,
# Nearest to a: roald, davidoff, categories, motels, fante, intersects, strains, construction,
# Nearest to bbc: businesspeople, interpreter, tom, servicing, promise, taxonomy, microfluidics, ezra,
# Nearest to pope: dario, bara, ans, niccolo, kaspar, lynch, husbands, calcutta,
# Nearest to derived: biotite, tabulate, broader, woodwinds, reputedly, judaeo, affront, anaphylaxis,
# Nearest to applied: bowie, spectral, cannot, cauchy, hawkwind, biathlon, kfar, conduction,
# Nearest to except: nearing, than, porosity, twins, arctos, burnside, synonymous, morrison,
# Nearest to scale: freemen, anecdote, worldwide, optical, multiplications, montreux, model, microsoft,
# Nearest to troops: delhi, mandarin, chardin, holidays, roo, moines, commander, entr,
# Nearest to engineering: example, kennewick, equipped, vinci, outlying, entorhinal, wrangler, liang,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4101 0.2515 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3815 0.2496 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4519 0.2497 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4005 0.2518 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4068 0.2508 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4348 0.2470 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3863 0.2495 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3739 0.2568 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4221 0.2507 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3647 0.2497 sec/batch
# Nearest to he: god, instructors, commit, reciting, gm, scatters, cured, worldcon,
# Nearest to their: darboux, prophetess, colds, worship, dgps, verge, ecsc, optimize,
# Nearest to over: injected, city, firefox, tourism, aggregates, horsepower, dollfuss, hanyu,
# Nearest to eight: five, one, interstates, adjutant, zero, basketball, duchess, seven,
# Nearest to may: sum, normalized, summarizing, desirable, insofar, bilingualism, express, barricades,
# Nearest to use: jacobian, refund, register, chanced, starve, phone, informative, lithosphere,
# Nearest to were: rabbits, herbivorous, farben, towel, poecilia, depot, commence, descendants,
# Nearest to a: roald, categories, construction, davidoff, phylogeny, fante, motels, probabilities,
# Nearest to bbc: businesspeople, tom, promise, servicing, taxonomy, microfluidics, interpreter, phone,
# Nearest to pope: bara, niccolo, dario, husbands, lynch, ans, kaspar, didache,
# Nearest to derived: biotite, tabulate, broader, root, reputedly, affront, demon, anaphylaxis,
# Nearest to applied: cannot, cauchy, spectral, hawkwind, gem, kfar, hypomania, biathlon,
# Nearest to except: nearing, than, twins, porosity, burnside, arctos, grids, all,
# Nearest to scale: worldwide, optical, freemen, anecdote, montreux, multiplications, planes, model,
# Nearest to troops: delhi, mandarin, chardin, roo, moines, commander, holidays, entr,
# Nearest to engineering: example, kennewick, equipped, entorhinal, vinci, outlying, systems, wrangler,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3937 0.2538 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3827 0.2546 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3660 0.2497 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3797 0.2518 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3636 0.2485 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3694 0.2546 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3884 0.2498 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3776 0.2506 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3111 0.2544 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3671 0.2505 sec/batch
# Nearest to he: god, commit, reciting, instructors, alois, worldcon, scatters, lawyers,
# Nearest to their: darboux, colds, prophetess, worship, dgps, affordable, abounds, heroics,
# Nearest to over: city, tourism, firefox, horsepower, dollfuss, injected, aggregates, blocs,
# Nearest to eight: five, one, zero, interstates, adjutant, seven, sucessful, rapport,
# Nearest to may: sum, normalized, desirable, insofar, bilingualism, stripping, summarizing, express,
# Nearest to use: jacobian, register, refund, informative, chanced, phone, starve, lithosphere,
# Nearest to were: rabbits, herbivorous, farben, chimborazo, depot, descendants, towel, commence,
# Nearest to a: roald, construction, intersects, davidoff, categories, phylogeny, motels, fante,
# Nearest to bbc: businesspeople, tom, interpreter, promise, microfluidics, taxonomy, phone, servicing,
# Nearest to pope: niccolo, dario, husbands, bara, pius, bishops, mourning, bishop,
# Nearest to derived: biotite, broader, tabulate, judaeo, arming, root, reputedly, demon,
# Nearest to applied: hawkwind, biathlon, kfar, hypomania, cauchy, bowie, determines, greenhouses,
# Nearest to except: than, twins, nearing, porosity, burnside, arctos, all, sweetness,
# Nearest to scale: worldwide, optical, anecdote, montreux, cameras, freemen, model, multiplications,
# Nearest to troops: delhi, roo, commander, mandarin, forces, chardin, defeated, blocked,
# Nearest to engineering: example, kennewick, equipped, vinci, entorhinal, outlying, postgraduate, applicant,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3620 0.2552 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3286 0.2531 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3804 0.2519 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3817 0.2505 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3737 0.2527 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2949 0.2527 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3046 0.2477 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3530 0.2497 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2320 0.2535 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3060 0.2511 sec/batch
# Nearest to he: god, reciting, scatters, instructors, alois, worldcon, weiser, commit,
# Nearest to their: darboux, prophetess, worship, colds, affordable, restraining, heroics, verge,
# Nearest to over: city, tourism, dollfuss, horsepower, firefox, tevet, blocs, large,
# Nearest to eight: five, one, zero, seven, interstates, duchess, adjutant, dickie,
# Nearest to may: normalized, bilingualism, sum, insofar, desirable, stripping, summarizing, or,
# Nearest to use: jacobian, register, refund, chanced, phone, informative, somali, ism,
# Nearest to were: rabbits, farben, herbivorous, commence, towel, chimborazo, descendants, rigidly,
# Nearest to a: roald, brunel, davidoff, fante, allele, perpetuating, motels, intersects,
# Nearest to bbc: businesspeople, microfluidics, tom, interpreter, observances, promise, rouge, taxonomy,
# Nearest to pope: niccolo, dario, bara, husbands, ans, pius, mourning, kaspar,
# Nearest to derived: biotite, broader, root, tabulate, arming, reputedly, affront, demon,
# Nearest to applied: biathlon, hawkwind, kfar, greenhouses, hypomania, cauchy, cannot, determines,
# Nearest to except: than, porosity, twins, nearing, burnside, arctos, mauritian, conic,
# Nearest to scale: worldwide, optical, anecdote, model, staccato, multiplications, cameras, export,
# Nearest to troops: delhi, roo, forces, commander, surrender, personnel, acre, blocked,
# Nearest to engineering: kennewick, example, vinci, equipped, postgraduate, entorhinal, outlying, wrangler,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2936 0.2527 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3001 0.2485 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3348 0.1207 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2517 0.2511 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2106 0.2492 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2178 0.2522 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2237 0.2514 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2268 0.2496 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2357 0.2523 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1746 0.2481 sec/batch
# Nearest to he: god, tortured, reciting, instructors, worldcon, scatters, weiser, brahmacharya,
# Nearest to their: darboux, affordable, prophetess, colds, worship, restraining, verge, howling,
# Nearest to over: city, dollfuss, firefox, horsepower, tourism, large, tevet, great,
# Nearest to eight: five, one, zero, interstates, adjutant, seven, sucessful, duchess,
# Nearest to may: normalized, insofar, desirable, sum, bilingualism, stripping, or, summarizing,
# Nearest to use: jacobian, register, refund, chanced, somali, phone, ism, starve,
# Nearest to were: rabbits, farben, descendants, herbivorous, commence, chimborazo, towel, esta,
# Nearest to a: roald, davidoff, brunel, fante, semi, approvals, avalokitesvara, perpetuating,
# Nearest to bbc: businesspeople, microfluidics, observances, interpreter, taxonomy, seamless, rouge, pbs,
# Nearest to pope: pius, niccolo, dario, bara, husbands, ans, bishops, mourning,
# Nearest to derived: broader, biotite, reputedly, steric, root, tabulate, arming, judaeo,
# Nearest to applied: biathlon, greenhouses, hawkwind, kfar, alike, hypomania, implications, cps,
# Nearest to except: than, porosity, twins, nearing, all, arctos, burnside, conic,
# Nearest to scale: worldwide, optical, anecdote, cameras, model, staccato, export, evaporate,
# Nearest to troops: delhi, roo, forces, surrender, commander, personnel, defeated, acre,
# Nearest to engineering: kennewick, example, vinci, postgraduate, entorhinal, wrangler, equipped, colleges,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2567 0.2531 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2158 0.2498 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2254 0.2498 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1028 0.2507 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2021 0.2506 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1609 0.2521 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1483 0.2513 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1872 0.2508 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2075 0.2493 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1944 0.2526 sec/batch
# Nearest to he: worldcon, god, brahmacharya, reciting, instructors, tortured, gm, scatters,
# Nearest to their: darboux, colds, affordable, worship, prophetess, restraining, dgps, howling,
# Nearest to over: dollfuss, city, horsepower, injected, firefox, great, tevet, hudson,
# Nearest to eight: five, one, zero, interstates, adjutant, sucessful, ccgs, seven,
# Nearest to may: normalized, desirable, sum, or, insofar, stripping, discharging, bilingualism,
# Nearest to use: jacobian, refund, chanced, register, somali, ism, lithosphere, informative,
# Nearest to were: rabbits, farben, commence, towel, descendants, chimborazo, rigidly, soaking,
# Nearest to a: davidoff, semi, intersects, allele, roald, inertial, majorities, categories,
# Nearest to bbc: businesspeople, microfluidics, phone, observances, pbs, interpreter, seamless, taxonomy,
# Nearest to pope: niccolo, pius, bara, dario, bishops, kaspar, ans, mourning,
# Nearest to derived: biotite, tabulate, reputedly, broader, steric, root, arming, affront,
# Nearest to applied: greenhouses, biathlon, hawkwind, hypomania, gem, kfar, cps, cauchy,
# Nearest to except: than, porosity, nearing, twins, all, arctos, mauritian, grids,
# Nearest to scale: worldwide, optical, model, cameras, anecdote, export, staccato, intervals,
# Nearest to troops: delhi, forces, roo, personnel, surrender, commander, defeated, blocked,
# Nearest to engineering: postgraduate, kennewick, example, colleges, vinci, entorhinal, wrangler, discipline,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1712 0.2537 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2120 0.2519 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1744 0.2519 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1455 0.2520 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2022 0.2528 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2037 0.2522 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1757 0.2535 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1279 0.2490 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1496 0.2509 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1574 0.2500 sec/batch
# Nearest to he: brahmacharya, worldcon, tortured, instructors, gm, god, his, maneuverable,
# Nearest to their: darboux, worship, colds, affordable, prophetess, howling, heroics, transgendered,
# Nearest to over: dollfuss, injected, horsepower, city, firefox, cmf, great, large,
# Nearest to eight: five, one, zero, seven, interstates, adjutant, nine, sucessful,
# Nearest to may: normalized, desirable, sum, or, stripping, discharging, insofar, bilingualism,
# Nearest to use: jacobian, chanced, refund, register, somali, modern, informative, ism,
# Nearest to were: rabbits, farben, towel, esta, herbivorous, descendants, poecilia, commence,
# Nearest to a: inertial, majorities, abbreviate, intersects, roald, davidoff, categories, allele,
# Nearest to bbc: businesspeople, microfluidics, phone, observances, pbs, taxonomy, interpreter, seamless,
# Nearest to pope: niccolo, pius, bishops, bara, kaspar, dario, ans, bishop,
# Nearest to derived: steric, tabulate, root, reputedly, biotite, broader, arming, derives,
# Nearest to applied: greenhouses, hypomania, biathlon, connectionist, alike, hawkwind, implications, gem,
# Nearest to except: than, porosity, twins, all, nearing, mauritian, burnside, conic,
# Nearest to scale: worldwide, optical, model, intervals, staccato, cameras, anecdote, crustal,
# Nearest to troops: delhi, roo, forces, commander, surrender, personnel, defeated, bombing,
# Nearest to engineering: postgraduate, entorhinal, discipline, kennewick, colleges, example, wrangler, vinci,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1882 0.2533 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1742 0.2511 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1558 0.2509 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1747 0.2516 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1673 0.2527 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1448 0.2477 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1780 0.2514 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1017 0.2523 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1780 0.2528 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2042 0.2524 sec/batch
# Nearest to he: was, worldcon, his, tortured, gm, brahmacharya, weiser, instructors,
# Nearest to their: darboux, worship, affordable, transgendered, heroics, prophetess, ecsc, colds,
# Nearest to over: dollfuss, firefox, cmf, horsepower, city, great, large, serious,
# Nearest to eight: one, five, seven, zero, nine, three, brackett, dickie,
# Nearest to may: normalized, discharging, or, stripping, bilingualism, insofar, desirable, sum,
# Nearest to use: refund, chanced, jacobian, register, ism, somali, phone, netware,
# Nearest to were: rabbits, farben, orders, esta, descendants, imprisoned, towel, bankruptcies,
# Nearest to a: majorities, abbreviate, davidoff, semi, routine, intersects, roald, avalokitesvara,
# Nearest to bbc: businesspeople, observances, pbs, microfluidics, phone, interpreter, itv, rouge,
# Nearest to pope: pius, bishops, niccolo, bara, ans, kaspar, patriarch, dario,
# Nearest to derived: reputedly, steric, root, tabulate, judaeo, biotite, phonetic, derives,
# Nearest to applied: greenhouses, biathlon, cps, kfar, alike, hypomania, gem, connectionist,
# Nearest to except: than, porosity, all, burnside, twins, mauritian, arctos, nearing,
# Nearest to scale: worldwide, anecdote, composers, optical, intervals, crustal, staccato, therese,
# Nearest to troops: delhi, roo, forces, personnel, surrender, commander, bombing, blocked,
# Nearest to engineering: postgraduate, kennewick, entorhinal, discipline, colleges, wrangler, vinci, liang,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2332 0.2536 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1250 0.2538 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1220 0.2503 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1461 0.2488 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0136 0.2529 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1574 0.2526 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1315 0.2519 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1385 0.2507 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1837 0.0570 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0964 0.2518 sec/batch
# Nearest to he: his, worldcon, was, tortured, maneuverable, gm, weiser, brahmacharya,
# Nearest to their: darboux, affordable, colds, transgendered, worship, howling, heroics, affidavit,
# Nearest to over: horsepower, dollfuss, cmf, firefox, injected, large, city, cno,
# Nearest to eight: one, five, seven, zero, three, nine, interstates, enzo,
# Nearest to may: normalized, or, accent, discharging, sum, desirable, stripping, bilingualism,
# Nearest to use: jacobian, refund, chanced, register, phone, somali, ism, netware,
# Nearest to were: rabbits, esta, orders, towel, descendants, farben, rigidly, bankruptcies,
# Nearest to a: abbreviate, inertial, intersects, is, semi, majorities, roald, lounge,
# Nearest to bbc: businesspeople, observances, pbs, phone, microfluidics, itv, taxonomy, seamless,
# Nearest to pope: pius, bara, ans, niccolo, bishops, kaspar, dario, bishop,
# Nearest to derived: tabulate, root, steric, reputedly, phonetic, biotite, derives, etymology,
# Nearest to applied: greenhouses, biathlon, alike, hypomania, cps, connectionist, gem, geodesic,
# Nearest to except: than, porosity, all, twins, arctos, mauritian, conic, nearing,
# Nearest to scale: worldwide, composers, optical, intervals, staccato, therese, anecdote, crustal,
# Nearest to troops: delhi, roo, forces, surrender, personnel, commander, bombing, blocked,
# Nearest to engineering: postgraduate, discipline, colleges, kennewick, entorhinal, liang, wrangler, innitzer,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0710 0.2636 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0726 0.2551 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0952 0.2514 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0579 0.2494 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0719 0.2527 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0573 0.2569 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1078 0.2580 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0987 0.2533 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1166 0.2517 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0138 0.2557 sec/batch
# Nearest to he: his, was, tortured, worldcon, maneuverable, weiser, gm, brahmacharya,
# Nearest to their: darboux, transgendered, colds, affordable, heroics, worship, filking, affidavit,
# Nearest to over: cmf, horsepower, dollfuss, city, firefox, large, estimated, serious,
# Nearest to eight: one, five, zero, seven, interstates, nine, three, enzo,
# Nearest to may: or, normalized, discharging, accent, bilingualism, sum, stripping, barricades,
# Nearest to use: jacobian, chanced, refund, register, ism, netware, modern, phone,
# Nearest to were: rabbits, orders, rigidly, farben, esta, chimborazo, bankruptcies, descendants,
# Nearest to a: is, majorities, semi, approvals, abbreviate, intersects, roald, rudder,
# Nearest to bbc: businesspeople, phone, pbs, observances, microfluidics, seamless, itv, waldensian,
# Nearest to pope: pius, kaspar, bishop, bishops, bara, ans, niccolo, dario,
# Nearest to derived: steric, tabulate, reputedly, arming, biotite, judaeo, root, etymology,
# Nearest to applied: greenhouses, biathlon, hypomania, alike, gem, cps, kfar, geodesic,
# Nearest to except: than, porosity, all, twins, mahilyow, nearing, burnside, arctos,
# Nearest to scale: worldwide, composers, anecdote, therese, optical, staccato, intervals, kildall,
# Nearest to troops: delhi, forces, roo, personnel, surrender, blocked, commander, bombing,
# Nearest to engineering: postgraduate, discipline, colleges, liang, entorhinal, kennewick, wrangler, innitzer,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0455 0.2541 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0505 0.2495 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0414 0.2509 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0399 0.2534 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0562 0.2503 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0547 0.2534 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0655 0.2494 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0948 0.2505 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0500 0.2534 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0437 0.2553 sec/batch
# Nearest to he: his, gm, worldcon, brahmacharya, was, maneuverable, slipped, tortured,
# Nearest to their: worship, darboux, heroics, affordable, transgendered, filking, howling, affidavit,
# Nearest to over: horsepower, injected, cmf, dollfuss, firefox, large, estimated, serious,
# Nearest to eight: one, five, seven, zero, nine, three, enzo, four,
# Nearest to may: or, normalized, discharging, sum, bilingualism, stripping, be, accent,
# Nearest to use: chanced, refund, jacobian, ism, prolific, register, somali, spawning,
# Nearest to were: rabbits, esta, orders, provided, bankruptcies, farben, descendants, rigidly,
# Nearest to a: is, abbreviate, argand, majorities, intersects, the, splits, torus,
# Nearest to bbc: businesspeople, phone, observances, pbs, itv, microfluidics, seamless, taxonomy,
# Nearest to pope: pius, kaspar, bishop, bishops, bara, ans, evangelicalism, niccolo,
# Nearest to derived: steric, tabulate, base, root, gel, biotite, reputedly, tile,
# Nearest to applied: greenhouses, hypomania, biathlon, gem, alike, connectionist, cps, kfar,
# Nearest to except: than, all, porosity, mahilyow, twins, burnside, gli, arctos,
# Nearest to scale: worldwide, composers, anecdote, intervals, optical, therese, dominate, staccato,
# Nearest to troops: roo, forces, delhi, surrender, personnel, blocked, await, commander,
# Nearest to engineering: postgraduate, discipline, colleges, entorhinal, liang, example, kennewick, tokyo,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0560 0.2576 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0522 0.2538 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0675 0.2522 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0548 0.2488 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0588 0.2525 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0795 0.2512 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0494 0.2505 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0526 0.2511 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0821 0.2516 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0674 0.2560 sec/batch
# Nearest to he: his, gm, was, worldcon, brahmacharya, weiser, tortured, maneuverable,
# Nearest to their: worship, transgendered, darboux, heroics, affordable, affidavit, tocharians, filking,
# Nearest to over: dollfuss, cmf, estimated, large, serious, city, horsepower, instructing,
# Nearest to eight: one, five, seven, zero, nine, three, four, enzo,
# Nearest to may: or, normalized, stripping, bilingualism, is, desirable, accent, discharging,
# Nearest to use: chanced, ism, refund, jacobian, register, scriptores, unfolding, spawning,
# Nearest to were: orders, rabbits, bankruptcies, expansionism, descendants, esta, failed, chimborazo,
# Nearest to a: majorities, argand, is, the, abbreviate, of, pontificate, gaels,
# Nearest to bbc: businesspeople, phone, observances, itv, pbs, microfluidics, waldensian, taxonomy,
# Nearest to pope: pius, bishops, bishop, kaspar, bara, ans, binitarians, prevailed,
# Nearest to derived: steric, reputedly, cognate, judaeo, derives, root, gel, overstated,
# Nearest to applied: greenhouses, alike, biathlon, gem, hypomania, cps, connectionist, kfar,
# Nearest to except: than, all, porosity, mahilyow, burnside, twins, mauritian, nearing,
# Nearest to scale: composers, worldwide, intervals, anecdote, kildall, therese, staccato, crustal,
# Nearest to troops: surrender, roo, forces, delhi, personnel, await, commander, blocked,
# Nearest to engineering: postgraduate, discipline, colleges, liang, entorhinal, kennewick, innitzer, equipped,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0629 0.2535 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0136 0.2518 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0477 0.2540 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0870 0.2525 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0677 0.2548 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1133 0.2525 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1282 0.2497 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0536 0.2499 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0309 0.2486 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0582 0.2494 sec/batch
# Nearest to he: his, gm, was, worldcon, brahmacharya, weiser, offered, instructors,
# Nearest to their: transgendered, affordable, darboux, heroics, worship, affidavit, hobbyists, othello,
# Nearest to over: horsepower, cmf, serious, estimated, firefox, large, dollfuss, parting,
# Nearest to eight: one, five, seven, zero, nine, three, four, brackett,
# Nearest to may: or, is, normalized, millimeters, stripping, accent, discharging, sum,
# Nearest to use: chanced, ism, netware, refund, jacobian, register, symbols, unfolding,
# Nearest to were: orders, bankruptcies, esta, rabbits, rigidly, descendants, expansionism, fortress,
# Nearest to a: is, argand, abbreviate, majorities, the, of, semi, splits,
# Nearest to bbc: observances, businesspeople, itv, pbs, phone, microfluidics, waldensian, news,
# Nearest to pope: pius, bara, bishop, bishops, kaspar, ans, binitarians, margarete,
# Nearest to derived: steric, reputedly, root, judaeo, base, cognate, tile, etymology,
# Nearest to applied: greenhouses, biathlon, alike, hypomania, cps, gem, kfar, connectionist,
# Nearest to except: than, all, porosity, mahilyow, burnside, mauritian, twins, nearing,
# Nearest to scale: composers, worldwide, intervals, anecdote, kildall, therese, staccato, crustal,
# Nearest to troops: surrender, roo, forces, delhi, personnel, await, blocked, bombing,
# Nearest to engineering: postgraduate, discipline, colleges, liang, entorhinal, kennewick, innitzer, vinci,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9710 0.2554 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0324 0.2577 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0462 0.2537 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0525 0.2556 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0681 0.2496 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0441 0.2403 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9954 0.2539 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0109 0.2528 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0036 0.2512 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9916 0.2502 sec/batch
# Nearest to he: his, was, brahmacharya, him, livia, tortured, gm, painting,
# Nearest to their: worship, darboux, transgendered, affordable, tocharians, vats, affidavit, hobbyists,
# Nearest to over: horsepower, serious, cmf, firefox, estimated, large, dollfuss, parting,
# Nearest to eight: one, five, seven, zero, nine, three, four, two,
# Nearest to may: or, accent, is, fc, millimeters, normalized, nadezhda, stripping,
# Nearest to use: chanced, refund, ism, reactivation, somali, netware, jacobian, unfolding,
# Nearest to were: orders, esta, bankruptcies, descendants, expansionism, rigidly, rabbits, nisus,
# Nearest to a: of, the, is, majorities, abbreviate, semi, movements, splits,
# Nearest to bbc: observances, businesspeople, pbs, phone, itv, march, feast, news,
# Nearest to pope: bishop, bara, pius, ans, kaspar, bishops, margarete, benedict,
# Nearest to derived: reputedly, etymology, steric, tabulate, derives, tile, overstated, judaeo,
# Nearest to applied: greenhouses, biathlon, alike, hypomania, gem, cps, kfar, connectionist,
# Nearest to except: than, porosity, all, mahilyow, morrison, burnside, twins, gli,
# Nearest to scale: intervals, composers, worldwide, anecdote, staccato, kildall, crustal, baglione,
# Nearest to troops: surrender, roo, forces, delhi, personnel, await, blocked, bombing,
# Nearest to engineering: postgraduate, discipline, colleges, liang, entorhinal, tokyo, kennewick, vinci,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9727 0.2547 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9501 0.2535 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0079 0.2511 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0292 0.2506 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0166 0.2512 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0023 0.2509 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8839 0.2498 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9576 0.2516 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9230 0.2497 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9789 0.2506 sec/batch
# Nearest to he: his, brahmacharya, was, him, gm, worldcon, offered, instructors,
# Nearest to their: heroics, transgendered, darboux, affordable, howling, and, affidavit, worship,
# Nearest to over: horsepower, serious, two, estimated, large, city, total, cmf,
# Nearest to eight: one, five, seven, zero, nine, three, four, two,
# Nearest to may: or, millimeters, normalized, is, stripping, fc, accent, offside,
# Nearest to use: chanced, refund, ism, somali, netware, reactivation, jacobian, countdown,
# Nearest to were: orders, bankruptcies, rigidly, esta, fortress, nisus, chimborazo, farben,
# Nearest to a: the, is, of, with, splits, semi, each, then,
# Nearest to bbc: observances, businesspeople, phone, itv, pbs, news, waldensian, kusachu,
# Nearest to pope: bara, kaspar, bishop, pius, bishops, ans, evangelicalism, cristiano,
# Nearest to derived: reputedly, steric, tile, etymology, tabulate, overstated, gel, palatalization,
# Nearest to applied: greenhouses, biathlon, alike, hypomania, cps, gem, kfar, connectionist,
# Nearest to except: than, porosity, all, mahilyow, morrison, twins, burnside, gli,
# Nearest to scale: composers, intervals, worldwide, anecdote, kildall, therese, staccato, underground,
# Nearest to troops: surrender, forces, roo, delhi, personnel, await, blocked, pershing,
# Nearest to engineering: postgraduate, discipline, liang, colleges, entorhinal, tokyo, kennewick, innitzer,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9889 0.2540 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0164 0.2518 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9739 0.2507 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9966 0.2505 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0452 0.2503 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9454 0.2497 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9908 0.2493 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9841 0.2517 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0119 0.2494 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9939 0.2552 sec/batch
# Nearest to he: his, was, gm, brahmacharya, him, worldcon, instructors, christophe,
# Nearest to their: heroics, transgendered, worship, stronger, affidavit, hobbyists, filking, tocharians,
# Nearest to over: serious, estimated, firefox, dollfuss, instructing, large, horsepower, cmf,
# Nearest to eight: one, five, seven, nine, zero, three, four, two,
# Nearest to may: or, millimeters, is, normalized, offside, sum, stripping, antibody,
# Nearest to use: chanced, refund, ism, countdown, unfolding, holder, netware, reactivation,
# Nearest to were: bankruptcies, orders, esta, nisus, expansionism, descendants, farben, rigidly,
# Nearest to a: the, is, of, argand, abbreviate, majorities, as, with,
# Nearest to bbc: observances, itv, businesspeople, phone, news, pbs, february, seamless,
# Nearest to pope: pius, bishops, bara, bishop, kaspar, ans, cristiano, theodora,
# Nearest to derived: tile, reputedly, gel, steric, tabulate, base, palatalization, derives,
# Nearest to applied: greenhouses, biathlon, hypomania, alike, cps, connectionist, gem, branches,
# Nearest to except: than, all, porosity, mahilyow, burnside, twins, morrison, apply,
# Nearest to scale: composers, intervals, anecdote, staccato, worldwide, kildall, dominate, therese,
# Nearest to troops: surrender, forces, roo, delhi, personnel, war, await, blocked,
# Nearest to engineering: postgraduate, discipline, liang, entorhinal, colleges, tokyo, kennewick, equipped,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0077 0.2536 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9837 0.2538 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9982 0.2552 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9975 0.2518 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0092 0.2519 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0093 0.2500 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9770 0.2590 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9477 0.2541 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9717 0.2487 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0469 0.2525 sec/batch
# Nearest to he: his, gm, was, him, brahmacharya, traveled, worldcon, maneuverable,
# Nearest to their: transgendered, worship, stronger, tocharians, filking, hobbyists, heroics, and,
# Nearest to over: serious, estimated, large, cmf, horsepower, dollfuss, total, instructing,
# Nearest to eight: one, five, seven, nine, zero, three, four, two,
# Nearest to may: or, is, millimeters, stripping, offside, normalized, discharging, accent,
# Nearest to use: chanced, ism, refund, netware, holder, participles, reactivation, still,
# Nearest to were: bankruptcies, orders, nisus, provided, fortress, expansionism, chimborazo, african,
# Nearest to a: the, of, is, as, in, with, majorities, argand,
# Nearest to bbc: observances, itv, businesspeople, news, phone, pbs, waldensian, march,
# Nearest to pope: bishops, pius, bishop, kaspar, bara, ans, margarete, cristiano,
# Nearest to derived: tile, reputedly, palatalization, gel, derives, overstated, judaeo, etymology,
# Nearest to applied: greenhouses, alike, biathlon, cps, hypomania, grotto, connectionist, kfar,
# Nearest to except: than, all, porosity, mahilyow, burnside, apply, morrison, conic,
# Nearest to scale: intervals, composers, anecdote, worldwide, kildall, staccato, therese, dominate,
# Nearest to troops: surrender, roo, forces, await, delhi, blocked, personnel, cheered,
# Nearest to engineering: discipline, postgraduate, liang, entorhinal, colleges, carlton, tokyo, equipped,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9629 0.2566 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0684 0.2586 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0378 0.2535 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0025 0.2523 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9534 0.2500 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9523 0.2486 sec/batch
# ...
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8348 0.2513 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8446 0.2508 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8577 0.2496 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8542 0.2487 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8438 0.2483 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9446 0.2488 sec/batch
# Nearest to he: his, him, gm, traveled, himself, brahmacharya, was, named,
# Nearest to their: them, they, to, are, were, and, most, filking,
# Nearest to over: two, five, four, zero, three, of, are, one,
# Nearest to eight: one, five, seven, nine, four, zero, three, two,
# Nearest to may: or, occasionally, offside, sometimes, which, are, sum, millimeters,
# Nearest to use: such, is, used, zimmermann, still, modulations, chanced, countdown,
# Nearest to were: nisus, orders, their, bankruptcies, could, provided, belonged, was,
# Nearest to a: the, of, in, an, is, with, to, and,
# Nearest to bbc: itv, observances, listing, march, day, news, pbs, feast,
# Nearest to pope: cristiano, rhetoricians, kaspar, gerlach, pius, bara, eagerly, urd,
# Nearest to derived: equivalent, asparagales, tile, deutscher, meaning, derives, bubblebath, etymology,
# Nearest to applied: biathlon, greenhouses, granted, branches, cps, hypomania, apply, alike,
# Nearest to except: all, than, morrison, porosity, unranked, burnside, mahilyow, foretells,
# Nearest to scale: intervals, composers, tuning, anecdote, gully, dred, staccato, kildall,
# Nearest to troops: surrender, await, forces, laboratories, barracks, roo, personnel, war,
# Nearest to engineering: postgraduate, discipline, liang, accredited, entorhinal, tokyo, vinci, melanin,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8528 0.2552 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8662 0.2522 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8505 0.2476 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8799 0.2516 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8697 0.2490 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9077 0.2483 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8352 0.2495 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8483 0.2496 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8493 0.2497 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8761 0.2521 sec/batch
# Nearest to he: his, traveled, him, was, himself, gm, brahmacharya, named,
# Nearest to their: them, they, were, and, to, are, most, filking,
# Nearest to over: two, five, four, zero, of, three, one, serious,
# Nearest to eight: one, five, nine, seven, four, zero, three, two,
# Nearest to may: or, occasionally, which, are, sum, is, sometimes, offside,
# Nearest to use: such, is, used, zimmermann, still, modulations, chanced, countdown,
# Nearest to were: orders, nisus, their, many, one, bankruptcies, of, and,
# Nearest to a: of, the, in, an, with, is, and, to,
# Nearest to bbc: itv, observances, listing, news, march, day, alexis, pbs,
# Nearest to pope: cristiano, rhetoricians, kaspar, binitarians, eagerly, bara, pius, gerlach,
# Nearest to derived: asparagales, equivalent, tile, deutscher, derives, meaning, greek, louisbourg,
# Nearest to applied: biathlon, greenhouses, alike, grotto, branches, granted, hypomania, rogan,
# Nearest to except: all, than, morrison, burnside, porosity, unranked, mahilyow, apply,
# Nearest to scale: intervals, composers, tuning, anecdote, dred, gully, kildall, veracity,
# Nearest to troops: surrender, await, forces, laboratories, war, dragoon, personnel, roo,
# Nearest to engineering: postgraduate, discipline, liang, entorhinal, melanin, accredited, vinci, tokyo,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8623 0.2530 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8230 0.2468 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8363 0.2501 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8221 0.2517 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8808 0.2509 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8708 0.2512 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9873 0.2525 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8908 0.2468 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8843 0.2542 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8111 0.2483 sec/batch
# Nearest to he: his, traveled, was, him, gm, career, himself, graduated,
# Nearest to their: them, they, and, were, affordable, darmstadt, most, filking,
# Nearest to over: two, four, five, zero, one, three, of, serious,
# Nearest to eight: one, five, seven, nine, four, zero, three, two,
# Nearest to may: or, occasionally, are, millimeters, twenty, which, offside, sum,
# Nearest to use: such, is, used, zimmermann, modulations, still, chanced, proposed,
# Nearest to were: orders, one, nisus, many, their, was, bankruptcies, the,
# Nearest to a: of, the, in, an, with, is, and, for,
# Nearest to bbc: itv, observances, listing, news, pbs, day, alexis, feast,
# Nearest to pope: cristiano, rhetoricians, benedict, kaspar, pius, youssef, bara, gerlach,
# Nearest to derived: asparagales, equivalent, tile, deutscher, derives, meaning, bubblebath, etymology,
# Nearest to applied: biathlon, greenhouses, granted, rogan, grotto, alike, branches, apply,
# Nearest to except: all, than, morrison, burnside, porosity, unranked, mahilyow, foretells,
# Nearest to scale: intervals, tuning, composers, dred, anecdote, gully, kildall, staccato,
# Nearest to troops: surrender, await, war, forces, laboratories, personnel, barracks, roo,
# Nearest to engineering: postgraduate, discipline, liang, entorhinal, tokyo, vinci, accredited, melanin,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8130 0.2499 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8258 0.2487 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7992 0.2527 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8626 0.2511 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8652 0.2480 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8739 0.2516 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8667 0.1632 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8627 0.2551 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8199 0.2529 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8704 0.2523 sec/batch
# Nearest to he: his, was, traveled, him, himself, had, brahmacharya, friend,
# Nearest to their: them, they, and, were, are, most, to, rather,
# Nearest to over: two, five, four, zero, serious, three, one, for,
# Nearest to eight: one, five, seven, nine, four, three, zero, six,
# Nearest to may: or, occasionally, twenty, which, sometimes, are, millimeters, as,
# Nearest to use: such, used, is, zimmermann, modulations, protecting, still, chanced,
# Nearest to were: nisus, their, orders, could, bankruptcies, are, belonged, was,
# Nearest to a: of, the, in, an, to, with, for, is,
# Nearest to bbc: observances, itv, listing, day, march, feast, news, pbs,
# Nearest to pope: cristiano, rhetoricians, gerlach, bara, youssef, kaspar, eagerly, permission,
# Nearest to derived: asparagales, equivalent, tile, derives, deutscher, etymology, meaning, louisbourg,
# Nearest to applied: biathlon, greenhouses, apply, spare, rogan, granted, alike, grotto,
# Nearest to except: all, than, morrison, burnside, unranked, porosity, mahilyow, foretells,
# Nearest to scale: intervals, tuning, composers, dred, gully, staccato, kildall, anecdote,
# Nearest to troops: surrender, await, laboratories, war, dragoon, personnel, forces, roo,
# Nearest to engineering: postgraduate, discipline, liang, entorhinal, accredited, vinci, colleges, melanin,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8058 0.2662 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8250 0.2557 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7784 0.2526 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8408 0.2504 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8418 0.2517 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8134 0.2501 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8820 0.2590 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7331 0.2466 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8152 0.2475 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7682 0.2494 sec/batch
# Nearest to he: his, him, traveled, was, himself, learned, gm, brahmacharya,
# Nearest to their: them, they, and, to, were, are, affordable, rather,
# Nearest to over: two, five, four, zero, three, one, of, are,
# Nearest to eight: one, five, nine, seven, four, zero, three, two,
# Nearest to may: or, occasionally, sometimes, commonly, are, twenty, which, as,
# Nearest to use: such, used, is, modulations, zimmermann, protecting, modern, still,
# Nearest to were: nisus, their, orders, belonged, could, one, are, had,
# Nearest to a: the, of, an, in, is, with, by, to,
# Nearest to bbc: itv, observances, listing, day, news, alexis, digs, feast,
# Nearest to pope: cristiano, rhetoricians, kaspar, benedict, binitarians, eagerly, youssef, gerlach,
# Nearest to derived: asparagales, equivalent, tile, deutscher, derives, meaning, etymology, the,
# Nearest to applied: biathlon, greenhouses, granted, spare, apply, rogan, branches, cps,
# Nearest to except: all, than, morrison, unranked, burnside, porosity, ketchum, foretells,
# Nearest to scale: intervals, composers, tuning, dred, gully, anecdote, kildall, staccato,
# Nearest to troops: surrender, await, forces, war, dragoon, personnel, delhi, counterattack,
# Nearest to engineering: postgraduate, discipline, liang, tokyo, entorhinal, accredited, colleges, melanin,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7709 0.2545 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8288 0.2501 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8448 0.2474 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7969 0.2484 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8043 0.2481 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9078 0.2532 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7956 0.2500 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8087 0.2540 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8426 0.2550 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8213 0.2590 sec/batch
# Nearest to he: his, him, traveled, was, himself, learned, gm, graduated,
# Nearest to their: they, them, and, were, are, to, most, as,
# Nearest to over: two, five, four, of, three, are, zero, one,
# Nearest to eight: one, nine, five, seven, four, zero, three, two,
# Nearest to may: or, occasionally, sometimes, are, which, as, commonly, sum,
# Nearest to use: such, is, used, still, zimmermann, modulations, protecting, countdown,
# Nearest to were: their, are, nisus, orders, many, bankruptcies, could, had,
# Nearest to a: the, of, an, is, in, with, this, by,
# Nearest to bbc: observances, itv, listing, day, digs, alexis, feast, kusachu,
# Nearest to pope: cristiano, rhetoricians, kaspar, binitarians, benedict, pius, gerlach, permission,
# Nearest to derived: asparagales, equivalent, deutscher, tile, derives, meaning, etymology, the,
# Nearest to applied: biathlon, greenhouses, apply, branches, granted, spare, cps, grotto,
# Nearest to except: all, than, morrison, burnside, unranked, apply, restricted, oni,
# Nearest to scale: intervals, composers, dred, tuning, gully, kildall, staccato, salce,
# Nearest to troops: surrender, await, dragoon, delhi, counterattack, war, roo, forces,
# Nearest to engineering: postgraduate, discipline, liang, entorhinal, accredited, melanin, aquilegia, tokyo,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8543 0.2507 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8478 0.2493 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8328 0.2505 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8154 0.2484 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8338 0.2527 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8615 0.2527 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8146 0.2501 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8584 0.2488 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8083 0.2517 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8274 0.2478 sec/batch
# Nearest to he: his, him, traveled, himself, was, gm, named, learned,
# Nearest to their: them, they, and, were, to, are, rather, most,
# Nearest to over: two, four, five, of, three, one, zero, are,
# Nearest to eight: one, five, nine, seven, four, zero, two, three,
# Nearest to may: or, are, which, occasionally, commonly, sometimes, as, is,
# Nearest to use: used, such, is, still, modulations, protecting, modern, countdown,
# Nearest to were: their, and, many, are, one, orders, the, had,
# Nearest to a: of, the, in, an, is, for, with, this,
# Nearest to bbc: observances, itv, listing, digs, day, news, alexis, feast,
# Nearest to pope: cristiano, rhetoricians, kaspar, altarpiece, binitarians, benedict, permission, pius,
# Nearest to derived: asparagales, derives, equivalent, tile, deutscher, etymology, as, the,
# Nearest to applied: biathlon, greenhouses, granted, branches, apply, cps, rogan, spare,
# Nearest to except: all, than, morrison, restricted, apply, burnside, unranked, mahilyow,
# Nearest to scale: intervals, dred, composers, gully, tuning, devouring, kildall, staccato,
# Nearest to troops: surrender, war, await, laboratories, forces, dragoon, barracks, personnel,
# Nearest to engineering: postgraduate, discipline, liang, entorhinal, bioinformatics, anthropologist, melanin, navi,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8635 0.2533 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8304 0.2518 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9487 0.2533 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9059 0.2486 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8835 0.2491 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8038 0.2482 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7688 0.2487 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8379 0.2486 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7551 0.2501 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8579 0.2488 sec/batch
# Nearest to he: his, him, traveled, himself, was, gm, career, friend,
# Nearest to their: them, they, and, were, affordable, rather, mmc, people,
# Nearest to over: two, four, zero, five, three, of, estimated, one,
# Nearest to eight: one, five, seven, nine, four, three, two, six,
# Nearest to may: or, occasionally, are, sometimes, as, commonly, is, twenty,
# Nearest to use: used, such, is, still, modulations, zimmermann, countdown, other,
# Nearest to were: their, and, are, have, many, had, orders, was,
# Nearest to a: of, the, an, in, is, with, to, for,
# Nearest to bbc: observances, listing, day, itv, feast, digs, news, alexis,
# Nearest to pope: cristiano, rhetoricians, benedict, kaspar, permission, bara, pius, gerlach,
# Nearest to derived: asparagales, equivalent, etymology, deutscher, tile, derives, meaning, bubblebath,
# Nearest to applied: biathlon, apply, greenhouses, granted, branches, spare, cps, publicise,
# Nearest to except: all, than, morrison, restricted, foretells, apply, burnside, mahilyow,
# Nearest to scale: intervals, composers, dred, tuning, staccato, devouring, gully, kildall,
# Nearest to troops: surrender, war, laboratories, barracks, await, forces, delhi, dragoon,
# Nearest to engineering: postgraduate, discipline, entorhinal, navi, liang, tokyo, bioinformatics, vinci,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8222 0.2520 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8336 0.2474 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], 
                 (embed_tsne[idx, 0], embed_tsne[idx, 1]), 
                 alpha=0.7)
